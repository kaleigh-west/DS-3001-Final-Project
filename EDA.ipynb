# %% [markdown]
# ## Read in Dataset

# %%
# Import pandas
import pandas as pd

# %%
# link to dataset info: https://archive.ics.uci.edu/dataset/544/estimation+of+obesity+levels+based+on+eating+habits+and+physical+condition
obesity_data_raw = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')
obesity_data_raw
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
# Rename columns for clarity
obesity_data_renamed = obesity_data_raw.rename(columns={'FAVC': 'high_freq_high_cal_intake',
                                                           'FCVC': 'vegetable_frequency',
                                                          'NCP': 'number_meals_per_day',
                                                          'CAEC': 'food_between_meals',
                                                          'CH2O': 'water_intake',
                                                          'SCC': 'monotor_daily_calories',
                                                          'FAF': 'physical_activity_freq',
                                                          'TUE': 'tech_time',
                                                          'CALC': 'alcohol_freq',
                                                          'MTRANS': 'transportation',
                                                          'NObeyesdad': 'obesity_level'})
obesity_data_renamed
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# %%
# Count NaNs
obesity_data_renamed.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# high_freq_high_cal_intake         0
# vegetable_frequency               0
# number_meals_per_day              0
# food_between_meals                0
# SMOKE                             0
# water_intake                      0
# monotor_daily_calories            0
# physical_activity_freq            0
# tech_time                         0
# alcohol_freq                      0
# transportation                    0
# obesity_level                     0
# dtype: int64

# %%
# See unique values in each non-numeric column

# Extract non-numeric columns
non_numeric_obesity = obesity_data_renamed.select_dtypes(exclude=['number'])

# List of all non-numeric column names to iterate through
column_names = non_numeric_obesity.columns.tolist()

# Make array of unique values in each column
unique_object_values = []
for column in column_names:
    unique_object_values.append(non_numeric_obesity[column].unique())

unique_object_values
# Out:
# [array(['Female', 'Male'], dtype=object),
#  array(['yes', 'no'], dtype=object),
#  array(['no', 'yes'], dtype=object),
#  array(['Sometimes', 'Frequently', 'Always', 'no'], dtype=object),
#  array(['no', 'yes'], dtype=object),
#  array(['no', 'yes'], dtype=object),
#  array(['no', 'Sometimes', 'Frequently', 'Always'], dtype=object),
#  array(['Public_Transportation', 'Walking', 'Automobile', 'Motorbike',
#         'Bike'], dtype=object),
#  array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#         'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#         'Obesity_Type_III'], dtype=object)]

# %%
# Count occurrences of each obesity level grouped by gender
obesity_counts = obesity_data_renamed.groupby(['obesity_level', 'Gender']).size().unstack(fill_value=0)
obesity_counts
# Out:
# Gender               Female  Male
# obesity_level
# Insufficient_Weight     173    99
# Normal_Weight           141   146
# Obesity_Type_I          156   195
# Obesity_Type_II           2   295
# Obesity_Type_III        323     1
# Overweight_Level_I      145   145
# Overweight_Level_II     103   187

# %%
# Create bar chart of obesity level counts by gender

# Define colors for each gender
color_map = {'Male': 'blue', 'Female': 'red'}

# Plot bar chart
ax = obesity_counts.plot(kind='bar', color=[color_map[col] for col in obesity_counts.columns], edgecolor='black')

# Add labels, title, and legend
ax.set_xlabel("Obesity Level")
ax.set_ylabel("Count")
ax.set_title("Obesity Level Counts by Gender")
ax.legend(title="Gender")

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()

# %%
# Count occurrences of each unique string
counts = obesity_data_renamed['obesity_level'].value_counts()
counts
# Out:
# obesity_level
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %%
# Extract labels and sizes
labels = counts.index  # Unique categories
sizes = counts.values  # Corresponding counts

# Plot pie chart
plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%')

plt.title('Target Frequency Distribution')
plt.show()

# %%
# Combine all obese/non-obese columns to make target values "Obese" and "Not Obese"

# Underweight Less than 18.5
# •Normal 18.5 to 24.9
# •Overweight 25.0 to 29.9
# •Obesity I 30.0 to 34.9
# •Obesity II 35.0 to 39.9
# •Obesity III Higher than 40

# Define which levels are considered "Obese"
obese_categories = ['Obesity_Type_I', 'Obesity_Type_II', 'Obesity_Type_III']

# Create a binary column: 1 if obese, 0 if not
obesity_data_renamed['Obese'] = obesity_data_renamed['obesity_level'].isin(obese_categories).astype(int)

obesity_data_renamed
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
# Count occurrences of each new obesity level grouped by gender
obesity_counts_new = obesity_data_renamed.groupby(['Obese', 'Gender']).size().unstack(fill_value=0)
obesity_counts_new
# Out:
# Gender  Female  Male
# Obese
# 0          562   577
# 1          481   491

# %%
# Create bar chart of obesity level counts by gender

# Define colors for each gender
color_map = {'Male': 'blue', 'Female': 'red'}

# Plot bar chart
ax_new = obesity_counts_new.plot(kind='bar', color=[color_map[col] for col in obesity_counts_new.columns], edgecolor='black')

# Add labels, title, and legend
ax_new.set_xlabel("Obesity Level")
ax_new.set_ylabel("Count")
ax_new.set_title("Obesity Level Counts by Gender")
ax_new.legend(title="Gender")

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()

# %%
# Count occurrences of each obesity level
counts_new = obesity_data_renamed['Obese'].value_counts()

# Extract labels and sizes
labels_new = ['Not_Obese', 'Obese']  # Unique categories
sizes_new = counts_new.values  # Corresponding counts

# Plot pie chart
plt.figure(figsize=(6,6))
plt.pie(sizes_new, labels=labels_new, autopct='%1.1f%%')

plt.title('Target Frequency Distribution')
plt.show()

# %%
# Combine visuals into subplots

# Create figure and subplots
fig, axs = plt.subplots(2, 2, tight_layout=True, figsize=(15, 10))

# Define bar chart colors
color_map = {'Male': 'blue', 'Female': 'red'}

# Non-combined pie chart
axs[0, 0].pie(sizes, labels=labels, autopct='%1.1f%%')
axs[0, 0].set_title('Original Obesity Level Frequency Distribution')

# Bar width for side-by-side bars
bar_width = 0.35  

# Set the x positions for bars (with offset for side-by-side bars)
x = np.arange(len(obesity_counts.index))  

# Plot bar chart for obesity counts by gender (ensuring side-by-side bars) in subplot [0][1]
for i, gender in enumerate(obesity_counts.columns):
    axs[0, 1].bar(x + i * bar_width, obesity_counts[gender], 
                  color=color_map[gender], edgecolor='black', 
                  width=bar_width, label=gender)

# Add labels, title, and legend
axs[0, 1].set_xlabel("Obesity Level")
axs[0, 1].set_ylabel("Count")
axs[0, 1].set_title("Original Obesity Level Counts by Gender")
axs[0, 1].set_xticks(x + bar_width / 2)  # Center the tick labels between bars
axs[0, 1].set_xticklabels(obesity_counts.index, rotation=30)
axs[0, 1].legend(title="Gender")

# Combined pie chart
axs[1, 0].pie(sizes_new, labels=labels_new, autopct='%1.1f%%')
axs[1, 0].set_title('Combined Obesity Level Frequency Distribution')

# Set the x positions for bars (with offset for side-by-side bars)
x1 = np.arange(len(obesity_counts_new.index)) 

# Combined bar chart in subplot [1][1] 
for i, gender in enumerate(obesity_counts_new.columns):
    axs[1, 1].bar(x1 + i * bar_width, obesity_counts_new[gender], 
                  color=color_map[gender], edgecolor='black', 
                  width=bar_width, label=gender)

# Labels for combined bar chart
axs[1, 1].set_xlabel("Obesity Level")
axs[1, 1].set_ylabel("Count")
axs[1, 1].set_title("Combined Obesity Level Counts by Gender")
axs[1, 1].set_xticks([0, 1])  # Only set the ticks at 0 and 1
axs[1, 1].set_xticks(x1 + bar_width / 2)  # Center the tick labels between bars
axs[1, 1].set_xticklabels(['Not_Obese', 'Obese']) 
axs[1, 1].legend(title="Gender")

plt.show()
